# %%
import matplotlib.pyplot as plt

def plot_circle_points(xc, yc, x, y, xes, yes):
    pts = [
        ( x + xc,  y + yc),
        (-x + xc,  y + yc),
        ( x + xc, -y + yc),
        (-x + xc, -y + yc),
        ( y + xc,  x + yc),
        (-y + xc,  x + yc),
        ( y + xc, -x + yc),
        (-y + xc, -x + yc)
    ]
    for px, py in pts:
        xes.append(px)
        yes.append(py)

def midpoint_circle(r, xc=0, yc=0):
    x = 0
    y = r
    p = 1 - r
    xes, yes = [], []

    plot_circle_points(xc, yc, x, y, xes, yes)

    while x < y:
        x += 1
        if p < 0:
            p = p + 2 * x + 1
        else:
            y -= 1
            p = p + 2 * (x - y) + 1
        plot_circle_points(xc, yc, x, y, xes, yes)

    return xes, yes

plt.figure(figsize=(6, 6))

x1, y1 = midpoint_circle(15, 0, 0)
plt.scatter(x1, y1, marker='.', label="r=15, center=(0,0)")

x2, y2 = midpoint_circle(10, 10, 10)
plt.scatter(x2, y2, marker='.', label="r=10, center=(10,10)")

x3, y3 = midpoint_circle(20, 15, 15)
plt.scatter(x3, y3, marker='.', label="r=20, center=(15,15)")

plt.title("Midpoint Circle - Different Radii & Centres")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.axis('equal')
plt.legend()
plt.show()
